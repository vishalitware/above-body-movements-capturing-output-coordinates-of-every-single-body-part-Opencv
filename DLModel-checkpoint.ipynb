# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras import optimizers
# Out:
# D:\anaconda file\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_x=pd.read_csv('F:/dataset/train_x.csv')
train_y=pd.read_csv('F:/dataset/train_y.csv')
test_x=pd.read_csv('F:/dataset/test_x.csv')
test_y=pd.read_csv('F:/dataset/test_y.csv')
train_x=train_x[['New_Board_W', 'New_Board_H', 'Artboard_width', 'Artboard_height', 'obj1L', 'obj1T',  'obj2L', 'obj2T',  'obj3L', 'obj3T',  'obj4L', 'obj4T']]
train_y=train_y[['obj1L', 'obj1T',  'obj2L', 'obj2T',  'obj3L', 'obj3T',  'obj4L', 'obj4T']]
test_x=test_x[['New_Board_W', 'New_Board_H', 'Artboard_width', 'Artboard_height', 'obj1L', 'obj1T',  'obj2L', 'obj2T',  'obj3L', 'obj3T',  'obj4L', 'obj4T']]
test_y=test_y[['obj1L', 'obj1T',  'obj2L', 'obj2T',  'obj3L', 'obj3T',  'obj4L', 'obj4T']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5fd00aeaa64f> in <module>()
# ----> 1 train_x=pd.read_csv('F:/dataset/train_x.csv')
#       2 train_y=pd.read_csv('F:/dataset/train_y.csv')
#       3 test_x=pd.read_csv('F:/dataset/test_x.csv')
#       4 test_y=pd.read_csv('F:/dataset/test_y.csv')
#       5 train_x=train_x[['New_Board_W', 'New_Board_H', 'Artboard_width', 'Artboard_height', 'obj1L', 'obj1T',  'obj2L', 'obj2T',  'obj3L', 'obj3T',  'obj4L', 'obj4T']]
#
# ...

# %%
train_y.columns
# Out:
# Index(['obj1L', 'obj1T', 'obj2L', 'obj2T', 'obj3L', 'obj3T', 'obj4L', 'obj4T'], dtype='object')

# %%
output_cols
# Out:
# 8

# %%
#create model
model = Sequential()

#get number of columns in training data
input_cols = train_x.shape[1]
output_cols = train_y.shape[1]

#add model layers
model.add(Dense(10, activation='sigmoid', input_shape=(input_cols,)))
model.add(Dense(10, activation='sigmoid'))
# model.add(Dense(10, activation='relu'))
# model.add(Dense(10, activation='relu'))
# model.add(Dense(10, activation='relu'))
model.add(Dense(output_cols))

# %%
 #compile model using mse as a measure of model performance
model.compile(optimizer='adam', loss='mean_squared_error')

from keras.callbacks import EarlyStopping
#set early stopping monitor so the model stops training when it won't improve anymore
early_stopping_monitor = EarlyStopping(patience=3)

# %%
#train model
model.fit(train_x, train_y, validation_split=0.2, epochs=500, callbacks=[early_stopping_monitor])
# Out:
# Train on 19 samples, validate on 5 samples
# Epoch 1/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5710 - val_loss: 1.6648
# Epoch 2/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5626 - val_loss: 1.6538
# Epoch 3/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5542 - val_loss: 1.6429
# Epoch 4/500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5459 - val_loss: 1.6320
# Epoch 5/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5377 - val_loss: 1.6212
# Epoch 6/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5296 - val_loss: 1.6105
# Epoch 7/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5216 - val_loss: 1.5999
# Epoch 8/500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5137 - val_loss: 1.5894
# Epoch 9/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5059 - val_loss: 1.5790
# Epoch 10/500
# ...

# %%
output = pd.DataFrame(model.predict(train_x))

# %%
print(output)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.401883  0.561446  0.805040  0.118506  0.440618  0.901652  0.464027
# 1   0.401883  0.561446  0.805040  0.118506  0.440618  0.901652  0.464027
# 2   0.655540  0.587978  0.993973  0.108323  0.593870  0.817764  0.530205
# 3   0.655540  0.587978  0.993973  0.108323  0.593870  0.817764  0.530205
# 4   0.231725  0.439414  0.509043  0.078389  0.288638  0.883991  0.368872
# 5   0.231725  0.439414  0.509043  0.078389  0.288638  0.883991  0.368872
# 6   0.401883  0.561446  0.805040  0.118506  0.440618  0.901652  0.464027
# 7   0.401883  0.561446  0.805040  0.118506  0.440618  0.901652  0.464027
# 8   0.401883  0.561446  0.805040  0.118506  0.440618  0.901652  0.464027
# 9   0.401883  0.561446  0.805040  0.118506  0.440618  0.901652  0.464027
# 10  0.231725  0.439414  0.509043  0.078389  0.288638  0.883991  0.368872
# 11  0.231725  0.439414  0.509043  0.078389  0.288638  0.883991  0.368872
# ...
